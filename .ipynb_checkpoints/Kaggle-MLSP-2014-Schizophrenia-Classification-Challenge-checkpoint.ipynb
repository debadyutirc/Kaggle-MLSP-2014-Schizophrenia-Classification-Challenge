# %%
# Helper Libs
import numpy as np
from scipy import stats
import pandas as pd
from time import time
import matplotlib.pyplot as plt

# ML Libs
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA

# %%
# File paths
outputFile = 'mlsp2014Solution.csv' # Will be created at the end

# From the Kaggle Data
# Train Feature Files
trainFNCFile = 'Train/train_FNC.csv'
trainSBMFile = 'Train/train_SBM.csv'
trainLabelsFile = 'Train/train_labels.csv'

# Test Feature Files
testFNCFile = 'Test/test_FNC.csv'
testSBMFile = 'Test/test_SBM.csv'

# %%
# Reading all the csv files into respective data frames for analysis
# Training data
trainFNC = pd.read_csv(trainFNCFile)
trainSBM = pd.read_csv(trainSBMFile)
Labels = pd.read_csv(trainLabelsFile)

# Testing data
testFNC = pd.read_csv(testFNCFile)
testSBM = pd.read_csv(testSBMFile)

# %%
trainIDs = trainFNC['Id']
trainFNCAn = trainFNC.drop(['Id'], axis=1)
trainSBMAn = trainSBM.drop(['Id'], axis=1)

trainData = pd.concat([trainFNCAn, trainSBMAn], axis=1)
trainLabels = Labels.drop(['Id'], axis=1)

# %%
trainData.head()
# Out:
#       FNC1      FNC2     FNC3     FNC4     FNC5      FNC6      FNC7      FNC8  \
# 0  0.34312  0.045761 -0.13112  0.15034  0.18082  0.289160  0.069545 -0.052489
# 1  0.28790  0.102570 -0.32343 -0.22776  0.12328  0.367020 -0.084040  0.038793
# 2  0.24585  0.216620 -0.12468 -0.35380  0.16150 -0.002032 -0.133020 -0.035222
# 3  0.42090  0.331380  0.24453  0.17167  0.59223  0.431050  0.280290  0.289620
# 4 -0.14621 -0.468630 -0.52880 -0.50381 -0.51052 -0.029113 -0.015192  0.360170
#
#        FNC9     FNC10    ...      SBM_map55  SBM_map61  SBM_map64  SBM_map67  \
# 0  0.124000  0.477620    ...      -0.078220  -0.982331   1.070363   0.220316
# 1 -0.006287  0.101690    ...       0.989571  -0.057543   0.371701  -0.513081
# 2  0.259040 -0.045302    ...      -0.257114   0.597229   1.220756  -0.059213
# 3  0.356800  0.286340    ...      -0.295110   0.829697  -0.450726  -0.791032
# 4  0.005944  0.024801    ...       1.342273  -0.978412   0.158492   0.889753
#
# ...

# %%
testIDs = testFNC['Id']
testFNCAn = testFNC.drop(['Id'], axis=1)
testSBMAn = testSBM.drop(['Id'], axis=1)

testData = pd.concat([testIDs, testFNCAn, testSBMAn], axis=1)
testDataAn = pd.concat([testFNCAn, testSBMAn], axis=1)

# %%
testDataAn.head()
# Out:
#        FNC1      FNC2      FNC3      FNC4      FNC5      FNC6      FNC7  \
# 0  0.476127  0.064466  0.053238 -0.608133  0.073988 -0.637039  0.113556
# 1  0.013833  0.267183  0.232178 -0.167151 -0.261327  0.191869  0.406493
# 2 -0.435452  0.046780  0.243742  0.397030 -0.147821  0.173620 -0.461963
# 3 -0.204510 -0.036735 -0.760705 -0.740495  0.064668  0.349926 -0.273826
# 4  0.599435 -0.166441  0.122431  0.011539  0.346906 -0.017430 -0.274734
#
#        FNC8      FNC9     FNC10    ...      SBM_map55  SBM_map61  SBM_map64  \
# 0 -0.192434 -0.004025 -0.060474    ...      -0.451994   1.123770   2.083006
# 1  0.088761  0.177048  0.036718    ...       0.696987   1.397832   1.046136
# 2 -0.610736  0.419753  0.400985    ...       0.160145   1.906989  -2.661633
# 3 -0.174384 -0.120248  0.175618    ...       0.974828  -1.997087  -2.083782
# 4  0.211510  0.151012 -0.033434    ...      -0.789153   1.578984   1.402592
#
# ...

# %%
pcaTest = PCA()
pcaTest.fit(trainData)

plt.plot(np.cumsum(pcaTest.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
# Out:
# Text(0,0.5,'Cumulative Explained Variance')

# %%
# Principal Component Analysis

t0 = time()
n_components = 70

pca = PCA(n_components, svd_solver='randomized', whiten=True)
pca.fit(trainData)

expRatio = 100 * pca.explained_variance_ratio_.sum()
print("Use of %d principal components explains %3.2f %% variance." % (n_components, expRatio))
print("PCA done in %0.3fs" % (time() - t0))
# Out:
# Use of 70 principal components explains 97.95 % variance.
# PCA done in 0.008s

# %%
trainDataTrx = pca.transform(trainData)

# %%
t0 = time()
C_range = np.logspace(-1, 4, num=8)
gamma_range = np.logspace(-4, 1, num=8)
parameters = dict(gamma=gamma_range, C=C_range)
model = svm.SVC(kernel='rbf')
random_state = 1
gs = GridSearchCV(estimator=model, param_grid=parameters, cv=5, n_jobs=-1, verbose=1)
gs = gs.fit(trainDataTrx, trainLabels)

print(gs.best_params_)

print("Search for best parameters done in %0.3fs" % (time() - t0))
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# /home/debadyuti/anaconda3/envs/python35/lib/python3.5/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/debadyuti/anaconda3/envs/python35/lib/python3.5/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/debadyuti/anaconda3/envs/python35/lib/python3.5/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
t0 = time()
# C_value = 71.96856730011521
# gamma_value = 0.0005179474679231213

# svmClf = svm.SVC(C=C_value, gamma=gamma_value, kernel='rbf', probability=True)
svmClf = svm.SVC(probability=True)
svmClf.fit(trainDataTrx, trainLabels)

print("Training SVM done in %0.3fs" % (time() - t0))
# Out:
# Training SVM done in 0.007s
# /home/debadyuti/anaconda3/envs/python35/lib/python3.5/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
testDataTrx = pca.transform(testDataAn)

# %%
random_state = 1
predictions = svmClf.predict_proba(testDataTrx)[:, 1]

# %%
predictions.shape
# Out:
# (119748,)

# %%
submission = {'ID' : testIDs, 
              'probability' : predictions}
submission = pd.DataFrame(submission)
submission.to_csv(outputFile, index = 0, float_format='%11.6f')
